# %% [markdown]
# <a href="https://colab.research.google.com/github/rhilderbrand/MSDS-422-MachineLearning/blob/main/Hilderbrand_Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 8: Language Modeling with a RNN

# %%
# !pip install tensorflow==1.14
# Out:
# Requirement already satisfied: tensorflow==1.14 in /usr/local/lib/python3.7/dist-packages (1.14.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.14.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.10.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (54.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.0)

# %%
# !pip install chakin
# Out:
# Requirement already satisfied: chakin in /usr/local/lib/python3.7/dist-packages (0.0.8)
# Requirement already satisfied: pandas>=0.20.1 in /usr/local/lib/python3.7/dist-packages (from chakin) (1.1.5)
# Requirement already satisfied: progressbar2>=3.20.0 in /usr/local/lib/python3.7/dist-packages (from chakin) (3.38.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from chakin) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.1->chakin) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.1->chakin) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.1->chakin) (1.19.5)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2>=3.20.0->chakin) (2.5.6)

# %%
import numpy as np
import tensorflow as tf

# Python chakin package previously installed by 
#    pip install chakin
import chakin  

import json
import os
from collections import defaultdict
import nltk 
nltk.download('stopwords')

import time
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
chakin.search(lang='English')  # lists available indices in English

# Specify English embeddings file to download and install
# by index number, number of dimensions, and subfoder name
# Note that GloVe 50-, 100-, 200-, and 300-dimensional folders
# are downloaded with a single zip download

CHAKIN_INDEX = 18
NUMBER_OF_DIMENSIONS = 50
SUBFOLDER_NAME = "glove.twitter.27B"

DATA_FOLDER = "embeddings"
ZIP_FILE = os.path.join(DATA_FOLDER, "{}.zip".format(SUBFOLDER_NAME))
ZIP_FILE_ALT = "glove" + ZIP_FILE[5:]  # sometimes it's lowercase only...
UNZIP_FOLDER = os.path.join(DATA_FOLDER, SUBFOLDER_NAME)
if SUBFOLDER_NAME[-1] == "d":
    GLOVE_FILENAME = os.path.join(
        UNZIP_FOLDER, "{}.txt".format(SUBFOLDER_NAME))
else:
    GLOVE_FILENAME = os.path.join(UNZIP_FOLDER, "{}.{}d.txt".format(
        SUBFOLDER_NAME, NUMBER_OF_DIMENSIONS))
    
if not os.path.exists(ZIP_FILE) and not os.path.exists(UNZIP_FOLDER):
    print("Downloading embeddings to '{}'".format(ZIP_FILE))
    chakin.download(number=CHAKIN_INDEX, save_dir='./{}'.format(DATA_FOLDER))
else:
    print("Embeddings already downloaded.")

if not os.path.exists(UNZIP_FOLDER):
    import zipfile
    if not os.path.exists(ZIP_FILE) and os.path.exists(ZIP_FILE_ALT):
        ZIP_FILE = ZIP_FILE_ALT
    with zipfile.ZipFile(ZIP_FILE, "r") as zip_ref:
        print("Extracting embeddings to '{}'".format(UNZIP_FOLDER))
        zip_ref.extractall(UNZIP_FOLDER)
else:
    print("Embeddings already extracted.")

print('\nRun complete')

# Do the same for a different vector/dimension

CHAKIN_INDEX = 11
NUMBER_OF_DIMENSIONS = 50
SUBFOLDER_NAME = "glove.6B"

DATA_FOLDER = "embeddings"
ZIP_FILE = os.path.join(DATA_FOLDER, "{}.zip".format(SUBFOLDER_NAME))
ZIP_FILE_ALT = "glove" + ZIP_FILE[5:]  # sometimes it's lowercase only...
UNZIP_FOLDER = os.path.join(DATA_FOLDER, SUBFOLDER_NAME)
if SUBFOLDER_NAME[-1] == "d":
    GLOVE_FILENAME = os.path.join(
        UNZIP_FOLDER, "{}.txt".format(SUBFOLDER_NAME))
else:
    GLOVE_FILENAME = os.path.join(UNZIP_FOLDER, "{}.{}d.txt".format(
        SUBFOLDER_NAME, NUMBER_OF_DIMENSIONS))
    
if not os.path.exists(ZIP_FILE) and not os.path.exists(UNZIP_FOLDER):
    print("Downloading embeddings to '{}'".format(ZIP_FILE))
    chakin.download(number=CHAKIN_INDEX, save_dir='./{}'.format(DATA_FOLDER))
else:
    print("Embeddings already downloaded.")

if not os.path.exists(UNZIP_FOLDER):
    import zipfile
    if not os.path.exists(ZIP_FILE) and os.path.exists(ZIP_FILE_ALT):
        ZIP_FILE = ZIP_FILE_ALT
    with zipfile.ZipFile(ZIP_FILE, "r") as zip_ref:
        print("Extracting embeddings to '{}'".format(UNZIP_FOLDER))
        zip_ref.extractall(UNZIP_FOLDER)
else:
    print("Embeddings already extracted.")

print('\nRun complete')
# Out:
#                    Name  Dimension  ... Language    Author
# 2          fastText(en)        300  ...  English  Facebook
# 11         GloVe.6B.50d         50  ...  English  Stanford
# 12        GloVe.6B.100d        100  ...  English  Stanford
# 13        GloVe.6B.200d        200  ...  English  Stanford
# 14        GloVe.6B.300d        300  ...  English  Stanford
# 15       GloVe.42B.300d        300  ...  English  Stanford
# 16      GloVe.840B.300d        300  ...  English  Stanford
# 17    GloVe.Twitter.25d         25  ...  English  Stanford
# 18    GloVe.Twitter.50d         50  ...  English  Stanford
# 19   GloVe.Twitter.100d        100  ...  English  Stanford
# 20   GloVe.Twitter.200d        200  ...  English  Stanford
# 21  word2vec.GoogleNews        300  ...  English    Google
#
# [12 rows x 7 columns]
# Embeddings already downloaded.
# Embeddings already extracted.
#
# Run complete
# Embeddings already downloaded.
# Embeddings already extracted.
#
# Run complete

# %%
# !ls -l embeddings
# Out:
# total 2326768
# drwxr-xr-x 2 root root       4096 Mar  3 16:03 glove.6B
# -rw-r--r-- 1 root root  862182613 Mar  3 16:03 glove.6B.zip
# drwxr-xr-x 2 root root       4096 Mar  3 15:55 glove.twitter.27B
# -rw-r--r-- 1 root root 1520408563 Mar  3 15:55 glove.twitter.27B.zip

# %% [markdown]
# ##Load Movie Reviews

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import re  # regular expressions
from collections import defaultdict
import nltk
from nltk.tokenize import TreebankWordTokenizer

RANDOM_SEED = 9999

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.getcwd()
# %cd /content/gdrive/My Drive/Colab Notebooks/Week 8/
# !pwd
# !ls
print('Working Directory')
print(os.getcwd())

work_dir = " /content/gdrive/My Drive/Colab Notebooks/Week 8/"
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Week 8
# /content/gdrive/My Drive/Colab Notebooks/Week 8
# Assignment8-GettingStarted.ipynb	    Hilderbrand_Assignment_8
# Assignment8-GettingStarted-Reference.ipynb  movie-reviews-negative
# embeddings				    movie-reviews-positive
# Working Directory
# /content/gdrive/My Drive/Colab Notebooks/Week 8

# %%
def reset_graph(seed= RANDOM_SEED):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
REMOVE_STOPWORDS = False  # no stopword removal

# %%
EVOCABSIZE = 1193515  # specify desired size of pre-defined embedding vocabulary

# %%
embeddings_directory = 'embeddings/glove.twitter.27B'
filename = 'glove.twitter.27B.100d.txt'

embeddings_filename = os.path.join(embeddings_directory, filename)
embeddings_filename
# Out:
# 'embeddings/glove.twitter.27B/glove.twitter.27B.100d.txt'

# %%
def load_embedding_from_disks(embeddings_filename, with_indexes=True):
    if with_indexes:
        word_to_index_dict = dict()
        index_to_embedding_array = []
  
    else:
        word_to_embedding_dict = dict()

    with open(embeddings_filename, 'r') as embeddings_file:
        for (i, line) in enumerate(embeddings_file):

            split = line.split(' ')

            word = split[0]

            representation = split[1:]
            representation = np.array(
                [float(val) for val in representation]
            )

            if with_indexes:
                word_to_index_dict[word] = i
                index_to_embedding_array.append(representation)
            else:
                word_to_embedding_dict[word] = representation

    # Empty representation for unknown words.
    _WORD_NOT_FOUND = [0.0] * len(representation)
    if with_indexes:
        _LAST_INDEX = i + 1
        word_to_index_dict = defaultdict(
            lambda: _LAST_INDEX, word_to_index_dict)
        index_to_embedding_array = np.array(
            index_to_embedding_array + [_WORD_NOT_FOUND])
        return word_to_index_dict, index_to_embedding_array
    else:
        word_to_embedding_dict = defaultdict(lambda: _WORD_NOT_FOUND)
        return word_to_embedding_dict

print('\nLoading embeddings from', embeddings_filename)
word_to_index, index_to_embedding = \
    load_embedding_from_disks(embeddings_filename, with_indexes=True)
print("Embedding loaded from disks.")
# Out:
# Loading embeddings from embeddings/glove.twitter.27B/glove.twitter.27B.100d.txt
# Embedding loaded from disks.

# %%
vocab_size, embedding_dim = index_to_embedding.shape
print("Embedding is of shape: {}".format(index_to_embedding.shape))
print("This means (number of words, number of dimensions per word)\n")
print("The first words are words that tend occur more often.")

print("Note: for unknown words, the representation is an empty vector,\n"
      "and the index is the last one. The dictionnary has a limit:")
print("    {} --> {} --> {}".format("A word", "Index in embedding", 
      "Representation"))
word = "worsdfkljsdf"  # a word obviously not in the vocabulary
idx = word_to_index[word] # index for word obviously not in the vocabulary
complete_vocabulary_size = idx 
embd = list(np.array(index_to_embedding[idx], dtype=int)) # "int" compact print
#print("    {} --> {} --> {}".format(word, idx, embd))
word = "the"
idx = word_to_index[word]
embd = list(index_to_embedding[idx])  # "int" for compact print only.
#print("    {} --> {} --> {}".format(word, idx, embd))
# Out:
# Embedding is of shape: (1193515, 100)
# This means (number of words, number of dimensions per word)
#
# The first words are words that tend occur more often.
# Note: for unknown words, the representation is an empty vector,
# and the index is the last one. The dictionnary has a limit:
#     A word --> Index in embedding --> Representation

# %%
# Show how to use embeddings dictionaries with a test sentence
# This is a famous typing exercise with all letters of the alphabet
# https://en.wikipedia.org/wiki/The_quick_brown_fox_jumps_over_the_lazy_dog
a_typing_test_sentence = 'The quick brown fox jumps over the lazy dog'
print('\nTest sentence: ', a_typing_test_sentence, '\n')
words_in_test_sentence = a_typing_test_sentence.split()

print('Test sentence embeddings from complete vocabulary of', 
      complete_vocabulary_size, 'words:\n')
for word in words_in_test_sentence:
    word_ = word.lower()
    embedding = index_to_embedding[word_to_index[word_]]
    print(word_ + ": ", embedding)
# Out:
# Test sentence:  The quick brown fox jumps over the lazy dog
#
# Test sentence embeddings from complete vocabulary of 1193514 words:
#
# the:  [ 9.5152e-02  3.7024e-01  5.4291e-01  1.9621e-01  4.8205e-02  3.2033e-01
#  -5.9638e-01  1.5868e-02 -1.2989e-01 -6.3028e-01  8.1944e-02  2.4164e-01
#  -6.0990e+00 -6.8557e-01  5.0354e-01 -3.4089e-02  1.1705e-01 -7.7403e-03
#  -8.6512e-02  4.3617e-01 -4.3982e-01  2.6125e-01 -4.0348e-02 -1.9194e-01
#   8.3204e-02 -5.8246e-01 -3.1923e-02  1.2630e-01  4.0120e-01  6.8906e-02
#  -1.0517e-01 -2.0804e-01 -4.2554e-01  4.7799e-01  3.4651e-01  2.4057e-01
#   5.0244e-02 -7.2587e-02 -2.4347e-03 -5.0342e-01 -1.0601e+00 -3.1586e-01
#  -3.2457e-02 -7.6317e-02  7.9045e-01  8.6367e-02 -1.9632e-01  5.7566e-02
#   8.4129e-01 -4.2020e-01 -1.1335e-03 -8.5632e-02  6.1910e-02  2.1423e-01
#  -1.0356e-01 -3.6946e-02 -2.6005e-01 -3.5657e-01  5.4321e-02  3.0875e-02
#   1.4092e-01 -9.1998e-02 -4.1841e-01 -3.1135e-01 -1.4937e-01 -2.2699e-04
#  -3.3454e-01 -1.4848e-01 -1.1944e-01 -2.7174e-01  3.1320e-01 -1.0998e-01
#  -4.7524e-01  1.4056e-01  3.9641e-01 -4.9413e-02 -4.2601e-01 -2.3576e-01
#   6.1482e-02 -3.5313e-02  2.4161e+00  2.8979e-01  3.8882e-01  3.6779e-01
#   2.0685e-01  1.3992e-01 -4.2459e-01  4.4590e-01  2.6234e-01 -4.4834e-01
#   3.7196e-03 -2.2521e-01  1.4764e-01 -3.6417e-01 -1.8493e-01  2.2282e-01
#   4.7626e-01 -5.1083e-01  4.6877e-01  3.4882e-01]
#   2.3714e-01  4.1720e-01 -1.6513e-01  1.8810e-01  7.0461e-01  2.5950e-01
#  -1.0690e-01  9.0640e-01  2.2023e-01 -1.9887e-01]
# dog:  [ 5.0779e-01 -1.0274e+00  4.8136e-01 -9.4170e-02  4.4837e-01 -5.2291e-01
#   5.1498e-01 -3.8927e-02  3.5867e-01 -6.5994e-02 -8.2882e-01  7.6179e-01
#  -3.8030e+00 -1.0576e-02  2.1654e-01  5.9712e-01  3.7424e-01 -2.2629e-02
#  -1.0331e-02 -3.3966e-01  9.4336e-02  2.6253e-01 -4.0161e-01 -7.9532e-03
#   1.0206e+00 -3.5793e-01 -5.6500e-01  5.8815e-01 -8.1847e-01  3.0293e-01
#   4.7199e-01 -9.7429e-02 -6.1226e-01 -1.7797e-01 -1.1616e-01  3.2586e-01
#   1.1498e-01 -1.9030e-01  1.1591e-02  4.6478e-01 -1.6805e-01  2.1972e-01
#  -2.5938e-01 -1.3541e-02  7.0714e-01  7.8106e-01  7.9917e-01  1.0389e+00
#   5.2792e-01 -1.1160e-01 -6.2275e-01  3.0692e-02  3.3847e-01 -5.3092e-01
#  -9.9688e-02  2.1596e-01  6.0522e-01  1.2356e+00 -3.4528e-03 -9.7514e-02
#  -2.4938e-01  2.1539e-01  4.4643e-01  9.5375e-02 -2.7366e-01 -2.8537e-01
#  -4.0894e-01  4.8223e-01  3.0318e-01  1.9440e-01  8.3242e-01 -5.0378e-01
#   3.0090e-01 -4.9792e-01  5.0297e-01  3.2685e-02 -5.1790e-01 -2.3541e-01
#   2.2960e-01 -6.3588e-01  1.6270e+00  6.2832e-01 -7.4846e-01  6.0073e-01
#  -1.1215e-02 -3.2113e-01  1.4339e-01 -6.0809e-02  8.8218e-02  6.5936e-01
#  -4.6127e-01 -3.7644e-01 -1.1330e-01  1.5875e-01  3.9119e-01  6.7659e-01
#  -7.1224e-02  1.7458e-01 -3.3406e-02  7.3152e-01]

# %%
def listdir_no_hidden(path):
    start_list = os.listdir(path)
    end_list = []
    for file in start_list:
        if (not file.startswith('.')):
            end_list.append(file)
    return(end_list)

# %%
# define list of codes to be dropped from document
# carriage-returns, line-feeds, tabs
codelist = ['\r', '\n', '\t']   

# We will not remove stopwords in this exercise because they are
# important to keeping sentences intact
if REMOVE_STOPWORDS:
    print(nltk.corpus.stopwords.words('english'))

# previous analysis of a list of top terms showed a number of words, along 
# with contractions and other word strings to drop from further analysis, add
# these to the usual English stopwords to be dropped from a document collection
    more_stop_words = ['cant','didnt','doesnt','dont','goes','isnt','hes',\
        'shes','thats','theres','theyre','wont','youll','youre','youve', 'br'\
        've', 're', 'vs'] 

    some_proper_nouns_to_remove = ['dick','ginger','hollywood','jack',\
        'jill','john','karloff','kudrow','orson','peter','tcm','tom',\
        'toni','welles','william','wolheim','nikita']

    # start with the initial list and add to it for movie text work 
    stoplist = nltk.corpus.stopwords.words('english') + more_stop_words +\
        some_proper_nouns_to_remove

# %%
# text parsing function for creating text documents 
# there is more we could do for data preparation 
# stemming... looking for contractions... possessives... 
# but we will work with what we have in this parsing function
# if we want to do stemming at a later time, we can use
#     porter = nltk.PorterStemmer()  
# in a construction like this
#     words_stemmed =  [porter.stem(word) for word in initial_words]  
def text_parse(string):
    # replace non-alphanumeric with space 
    temp_string = re.sub('[^a-zA-Z]', '  ', string)    
    # replace codes with space
    for i in range(len(codelist)):
        stopstring = ' ' + codelist[i] + '  '
        temp_string = re.sub(stopstring, '  ', temp_string)      
    # replace single-character words with space
    temp_string = re.sub('\s.\s', ' ', temp_string)   
    # convert uppercase to lowercase
    temp_string = temp_string.lower()    
    if REMOVE_STOPWORDS:
        # replace selected character strings/stop-words with space
        for i in range(len(stoplist)):
            stopstring = ' ' + str(stoplist[i]) + ' '
            temp_string = re.sub(stopstring, ' ', temp_string)        
    # replace multiple blank characters with one blank character
    temp_string = re.sub('\s+', ' ', temp_string)    
    return(temp_string)

# %%
# -----------------------------------------------
# gather data for 500 negative movie reviews
# -----------------------------------------------

dir_name = 'movie-reviews-negative'
filenames = listdir_no_hidden(path=dir_name)
num_files = len(filenames)

for i in range(len(filenames)):
    file_exists = os.path.isfile(os.path.join(dir_name, filenames[i]))
    assert file_exists
print('\nDirectory:',dir_name)    
print('%d files found' % len(filenames))
# Out:
# Directory: movie-reviews-negative
# 500 files found

# %%
# Read data for negative movie reviews
# Data will be stored in a list of lists where the each list represents 
# a document and document is a list of words.
# We then break the text into words.

def read_data(filename):

  with open(filename, encoding='utf-8') as f:
    data = tf.compat.as_str(f.read())
    data = data.lower()
    data = text_parse(data)
    data = TreebankWordTokenizer().tokenize(data)  # The Penn Treebank

  return data

negative_documents = []

print('\nProcessing document files under', dir_name)
for i in range(num_files):
    ## print(' ', filenames[i])

    words = read_data(os.path.join(dir_name, filenames[i]))

    negative_documents.append(words)
    # print('Data size (Characters) (Document %d) %d' %(i,len(words)))
    # print('Sample string (Document %d) %s'%(i,words[:50]))
# Out:
# Processing document files under movie-reviews-negative

# %%
# -----------------------------------------------
# gather data for 500 positive movie reviews
# -----------------------------------------------

# Set path to the positive word dictionary, "moive-reviews-positive"
dir_name = 'movie-reviews-positive'  
filenames = listdir_no_hidden(path=dir_name)
num_files = len(filenames)

for i in range(len(filenames)):
    file_exists = os.path.isfile(os.path.join(dir_name, filenames[i]))
    assert file_exists
print('\nDirectory:',dir_name)    
print('%d files found' % len(filenames))
# Out:
# Directory: movie-reviews-positive
# 500 files found

# %%
# Read data for positive movie reviews
# Data will be stored in a list of lists where the each list 
# represents a document and document is a list of words.
# We then break the text into words.

def read_data(filename):

  with open(filename, encoding='utf-8') as f:
    data = tf.compat.as_str(f.read())
    data = data.lower()
    data = text_parse(data)
    data = TreebankWordTokenizer().tokenize(data)  # The Penn Treebank

  return data

positive_documents = []

print('\nProcessing document files under', dir_name)
for i in range(num_files):
    ## print(' ', filenames[i])

    words = read_data(os.path.join(dir_name, filenames[i]))

    positive_documents.append(words)
    # print('Data size (Characters) (Document %d) %d' %(i,len(words)))
    # print('Sample string (Document %d) %s'%(i,words[:50]))
# Out:
# Processing document files under movie-reviews-positive

# %%
# -----------------------------------------------------
# convert positive/negative documents into numpy array
# note that reviews vary from 22 to 1052 words   
# so we use the first 20 and last 20 words of each review 
# as our word sequences for analysis
# -----------------------------------------------------

max_review_length = 0  # initialize
for doc in negative_documents:
    max_review_length = max(max_review_length, len(doc))    
for doc in positive_documents:
    max_review_length = max(max_review_length, len(doc)) 
print('max_review_length:', max_review_length) 

min_review_length = max_review_length  # initialize
for doc in negative_documents:
    min_review_length = min(min_review_length, len(doc))    
for doc in positive_documents:
    min_review_length = min(min_review_length, len(doc)) 
print('min_review_length:', min_review_length)
# Out:
# max_review_length: 1052
# min_review_length: 22

# %%
# construct list of 1000 lists with 20 words in each list
from itertools import chain
documents = []
for doc in negative_documents:
    doc_begin = doc[0:20]
    doc_end = doc[len(doc) - 20: len(doc)]
    documents.append(list(chain(*[doc_begin, doc_end])))    
for doc in positive_documents:
    doc_begin = doc[0:20]
    doc_end = doc[len(doc) - 20: len(doc)]
    documents.append(list(chain(*[doc_begin, doc_end])))

# %%
# create list of lists of lists for embeddings
embeddings = []    
for doc in documents:
    embedding = []
    for word in doc:
       embedding.append(limited_index_to_embedding[limited_word_to_index[word]]) 
    embeddings.append(embedding)

# %%
# -----------------------------------------------------    
# Check on the embeddings list of list of lists 
# -----------------------------------------------------

# Show the first word in the first document
test_word = documents[0][0]    
print('First word in first document:', test_word)    
print('Embedding for this word:\n', 
      limited_index_to_embedding[limited_word_to_index[test_word]])
print('Corresponding embedding from embeddings list of list of lists\n',
      embeddings[0][0][:])
# Out:
# First word in first document: which
# Embedding for this word:
#  [ 6.0889e-01 -1.5984e-01  1.4736e-02  2.1820e-01 -6.5285e-02  7.3514e-01
#  -1.0952e-01 -1.6179e-01  4.5139e-01  9.5813e-02 -1.6871e-01 -4.9643e-02
#  -4.9057e+00  3.0738e-01  2.5214e-01  4.9240e-02  4.4719e-01 -1.6793e-01
#   2.4007e-01 -3.0969e-01  6.5843e-01 -5.4774e-02 -7.8483e-02  2.0751e-01
#  -4.6869e-01  8.6805e-01 -1.1367e-01 -2.4647e-03  7.2583e-01  4.3149e-01
#   1.7677e-01  4.8115e-01 -5.7486e-01  2.1824e-01 -1.7964e-01 -3.0690e-01
#   4.2665e-01 -9.0761e-03 -5.6024e-02 -3.7428e-01 -1.8050e-01 -4.2520e-01
#  -1.4096e-02 -1.3010e-01  3.2657e-01 -3.8306e-01  1.9153e-01 -5.5832e-01
#  -1.2624e-01 -3.6936e-01  2.8686e-01  1.3025e-01 -2.9291e-01  1.9413e-01
#  -1.7419e-01  3.8364e-01  6.7937e-02  9.1995e-02 -4.6295e-01 -4.4111e-02
#  -2.9891e-01  8.5749e-02 -4.4849e-02  1.0723e-01  7.0104e-01 -1.4911e-01
#   2.2425e-01 -2.5331e-01 -5.8767e-02  3.5389e-02 -2.9128e-01 -7.1325e-01
#  -1.3492e-01 -4.2722e-01  6.0222e-01 -4.2433e-01 -2.5167e-01  2.1442e-01
#  -1.9909e-01 -2.3798e-01  1.8509e+00 -1.7961e-01  5.1304e-02  1.4844e-02
                     random_state = RANDOM_SEED)

# %% [markdown]
# ##Model 1 - RNN variations using embedding: Glove.twitter 100d/1.2M words

# %% [markdown]
# ###Model 1a - simple RNN (100d)
#
# train accuracy: 0.9
#
# test accuracy: 0.585
#
# time:

# %%
# --------------------------------------------------------------------------      
# We use a very simple Recurrent Neural Network for this assignment
# Géron, A. 2017. Hands-On Machine Learning with Scikit-Learn & TensorFlow: 
#    Concepts, Tools, and Techniques to Build Intelligent Systems. 
#    Sebastopol, Calif.: O'Reilly. [ISBN-13 978-1-491-96229-9] 
#    Chapter 14 Recurrent Neural Networks, pages 390-391
#    Source code available at https://github.com/ageron/handson-ml
#    Jupyter notebook file 14_recurrent_neural_networks.ipynb
#    See section on Training an sequence Classifier, # In [34]:
#    which uses the MNIST case data...  we revise to accommodate
#    the movie review data in this assignment    
# --------------------------------------------------------------------------  
# %%time
reset_graph()

### Consutruction Phase ###

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up

learning_rate = 0.001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

basic_cell = tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
outputs, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)

logits = tf.layers.dense(states, n_outputs)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                          logits=logits)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

n_epochs = 50
batch_size = 100

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1a889b3d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1a889b3d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1a889b3d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1a889b3d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ac4c1f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ac4c1f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ac4c1f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ac4c1f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
#   ---- Epoch  0  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.52 Test accuracy: 0.525
#
#   ---- Epoch  1  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.55 Test accuracy: 0.57
#
#   ---- Epoch  2  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.63 Test accuracy: 0.565
#
#   ---- Epoch  3  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.66 Test accuracy: 0.545
#
#   ---- Epoch  4  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.68 Test accuracy: 0.55
#
#   ---- Epoch  5  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.69 Test accuracy: 0.545
#
#   ---- Epoch  6  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.69 Test accuracy: 0.545
#
#   ---- Epoch  7  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.71 Test accuracy: 0.55
#
#   ---- Epoch  8  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.57
#
#   ---- Epoch  9  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.575
#
#   ---- Epoch  10  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.59
#
#   ---- Epoch  11  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.605
#
#   ---- Epoch  12  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.59
#
#   ---- Epoch  13  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.585
#
#   ---- Epoch  14  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.595
#
#   ---- Epoch  15  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.88 Test accuracy: 0.6
#
#   ---- Epoch  16  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.605
#
#   ---- Epoch  17  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.605
#
#   ---- Epoch  18  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.9 Test accuracy: 0.605
#
#   ---- Epoch  19  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.595
#
#   ---- Epoch  20  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.91 Test accuracy: 0.59
#
#   ---- Epoch  21  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.595
#
#   ---- Epoch  22  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.91 Test accuracy: 0.605
#
#   ---- Epoch  23  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.605
#
#   ---- Epoch  24  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.615
#
#   ---- Epoch  25  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.93 Test accuracy: 0.61
#
#   ---- Epoch  26  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.6
#
#   ---- Epoch  27  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.94 Test accuracy: 0.615
#
#   ---- Epoch  28  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.95 Test accuracy: 0.615
#
#   ---- Epoch  29  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.62
#
#   ---- Epoch  30  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.61
#
#   ---- Epoch  31  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.615
#
#   ---- Epoch  32  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.61
#
#   ---- Epoch  33  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.625
#
#   ---- Epoch  34  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.63
#
#   ---- Epoch  35  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.615
#
#   ---- Epoch  36  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.605
#
#   ---- Epoch  37  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.625
#
#   ---- Epoch  38  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.605
#
#   ---- Epoch  39  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.61
#
#   ---- Epoch  40  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.62
#
#   ---- Epoch  41  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.625
#
#   ---- Epoch  42  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.61
#
#   ---- Epoch  43  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.61
#
#   ---- Epoch  44  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.62
#
#   ---- Epoch  45  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.64
#
#   ---- Epoch  46  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.625
#
#   ---- Epoch  47  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.625
#
#   ---- Epoch  48  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.635
#
#   ---- Epoch  49  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.65
# CPU times: user 16.9 s, sys: 769 ms, total: 17.7 s
# Wall time: 10.8 s

# %% [markdown]
# ###Model 1b - Long Short Term Memory (LSTM) Model

# %%
# %%time
reset_graph()

lstm_cell = tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up
n_layers = 3

learning_rate = 0.0001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

lstm_cells = [tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)
              for layer in range(n_layers)]
multi_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)
outputs, states = tf.nn.dynamic_rnn(multi_cell, X, dtype=tf.float32)
top_layer_h_state = states[-1][1]
logits = tf.layers.dense(top_layer_h_state, n_outputs, name="softmax")
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy, name="loss")
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

n_epochs = 50
batch_size = 100

'''with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print("Epoch", epoch, "Train accuracy =", acc_train, "Test accuracy =", acc_test)'''

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:From <timed exec>:3: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <timed exec>:18: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb19a1d3250>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb19a1d3250>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb19a1d3250>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb19a1d3250>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbdd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbdd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbdd0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbdd0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbe90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbe90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1d3410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1d3410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1d3410>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1d3410>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19a1d3390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19a1d3390>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19a1d3390>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19a1d3390>>: AssertionError: Bad argument number for Name: 3, expecting 4
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 0 Train accuracy = 0.57 Test accuracy = 0.605
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 1 Train accuracy = 0.57 Test accuracy = 0.615
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 2 Train accuracy = 0.59 Test accuracy = 0.605
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 3 Train accuracy = 0.61 Test accuracy = 0.61
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 4 Train accuracy = 0.63 Test accuracy = 0.605
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 5 Train accuracy = 0.65 Test accuracy = 0.61
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 6 Train accuracy = 0.65 Test accuracy = 0.6
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 7 Train accuracy = 0.66 Test accuracy = 0.625
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 8 Train accuracy = 0.66 Test accuracy = 0.64
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 9 Train accuracy = 0.7 Test accuracy = 0.665
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 10 Train accuracy = 0.73 Test accuracy = 0.675
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 11 Train accuracy = 0.73 Test accuracy = 0.67
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 12 Train accuracy = 0.73 Test accuracy = 0.675
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 13 Train accuracy = 0.73 Test accuracy = 0.685
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 14 Train accuracy = 0.76 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 15 Train accuracy = 0.75 Test accuracy = 0.695
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 16 Train accuracy = 0.77 Test accuracy = 0.705
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 17 Train accuracy = 0.78 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 18 Train accuracy = 0.79 Test accuracy = 0.695
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 19 Train accuracy = 0.8 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 20 Train accuracy = 0.78 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 21 Train accuracy = 0.77 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 22 Train accuracy = 0.78 Test accuracy = 0.705
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 23 Train accuracy = 0.79 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 24 Train accuracy = 0.78 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 25 Train accuracy = 0.78 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 26 Train accuracy = 0.78 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 27 Train accuracy = 0.78 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 28 Train accuracy = 0.81 Test accuracy = 0.72
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 29 Train accuracy = 0.83 Test accuracy = 0.725
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 30 Train accuracy = 0.83 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 31 Train accuracy = 0.81 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 32 Train accuracy = 0.81 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 33 Train accuracy = 0.81 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 34 Train accuracy = 0.82 Test accuracy = 0.735
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 35 Train accuracy = 0.82 Test accuracy = 0.74
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 36 Train accuracy = 0.82 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 37 Train accuracy = 0.82 Test accuracy = 0.74
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 38 Train accuracy = 0.82 Test accuracy = 0.74
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 39 Train accuracy = 0.82 Test accuracy = 0.74
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 40 Train accuracy = 0.82 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 41 Train accuracy = 0.82 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 42 Train accuracy = 0.81 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 43 Train accuracy = 0.81 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 44 Train accuracy = 0.81 Test accuracy = 0.745
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 45 Train accuracy = 0.81 Test accuracy = 0.75
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 46 Train accuracy = 0.8 Test accuracy = 0.75
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 47 Train accuracy = 0.8 Test accuracy = 0.75
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 48 Train accuracy = 0.8 Test accuracy = 0.75
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 49 Train accuracy = 0.81 Test accuracy = 0.755
# CPU times: user 29.8 s, sys: 1.51 s, total: 31.3 s
# Wall time: 18.2 s

# %% [markdown]
# ###Model 1c - RNN model using drop cell (100d)
#
# train accuracy:
# test accuracy:
# time:

# %%
# %%time
reset_graph()

# lstm_cell = tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up
n_layers = 3

learning_rate = 0.001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

keep_prob = tf.placeholder_with_default(.95, shape=())
cells = [tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
         for layer in range(n_layers)]
cells_drop = [tf.contrib.rnn.DropoutWrapper(cell, input_keep_prob=keep_prob)
              for cell in cells]
multi_layer_cell = tf.contrib.rnn.MultiRNNCell(cells_drop)
outputs, states = tf.nn.dynamic_rnn(multi_layer_cell, X, dtype=tf.float32)

states_concat = tf.concat(axis=1, values=states)
logits = tf.layers.dense(states_concat, n_outputs)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
        
n_epochs = 100
batch_size = 100

'''with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(y_train.shape[0] // batch_size):
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            X_batch = X_batch.reshape((-1, n_steps, n_inputs))
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)'''

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a64850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a64850>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a64850>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a64850>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a647d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a647d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a647d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a647d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a64b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a64b90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a64b90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method
# 97 Train accuracy: 0.98 Test accuracy: 0.645
# 98 Train accuracy: 1.0 Test accuracy: 0.615
# 99 Train accuracy: 0.99 Test accuracy: 0.6
# CPU times: user 37.8 s, sys: 1.5 s, total: 39.3 s
# Wall time: 22.6 s

# %% [markdown]
# ##Model 2 - RNN variations using embedding: Glove.6B 300d/400k words

# %%
def reset_graph(seed= RANDOM_SEED):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

REMOVE_STOPWORDS = False  # no stopword removal 
EVOCABSIZE = 400000

embeddings_directory = 'embeddings/glove.6B'
filename = 'glove.6B.300d.txt'

embeddings_filename = os.path.join(embeddings_directory, filename)
embeddings_filename
# Out:
# 'embeddings/glove.6B/glove.6B.300d.txt'

# %%
def load_embedding_from_disks(embeddings_filename, with_indexes=True):
    if with_indexes:
        word_to_index_dict = dict()
        index_to_embedding_array = []
  
    else:
        word_to_embedding_dict = dict()

    with open(embeddings_filename, 'r') as embeddings_file:
        for (i, line) in enumerate(embeddings_file):

            split = line.split(' ')

            word = split[0]

            representation = split[1:]
            representation = np.array(
                [float(val) for val in representation]
            )

            if with_indexes:
                word_to_index_dict[word] = i
                index_to_embedding_array.append(representation)
            else:
                word_to_embedding_dict[word] = representation

    # Empty representation for unknown words.
    _WORD_NOT_FOUND = [0.0] * len(representation)
    if with_indexes:
        _LAST_INDEX = i + 1
        word_to_index_dict = defaultdict(
            lambda: _LAST_INDEX, word_to_index_dict)
        index_to_embedding_array = np.array(
            index_to_embedding_array + [_WORD_NOT_FOUND])
        return word_to_index_dict, index_to_embedding_array
    else:
        word_to_embedding_dict = defaultdict(lambda: _WORD_NOT_FOUND)
        return word_to_embedding_dict

print('\nLoading embeddings from', embeddings_filename)
word_to_index, index_to_embedding = \
    load_embedding_from_disks(embeddings_filename, with_indexes=True)
print("Embedding loaded from disks.")
# Out:
# Loading embeddings from embeddings/glove.6B/glove.6B.300d.txt
# Embedding loaded from disks.

# %%
vocab_size, embedding_dim = index_to_embedding.shape
print("Embedding is of shape: {}".format(index_to_embedding.shape))
print("This means (number of words, number of dimensions per word)\n")
print("The first words are words that tend occur more often.")

print("Note: for unknown words, the representation is an empty vector,\n"
      "and the index is the last one. The dictionnary has a limit:")
print("    {} --> {} --> {}".format("A word", "Index in embedding", 
      "Representation"))
word = "worsdfkljsdf"  # a word obviously not in the vocabulary
idx = word_to_index[word] # index for word obviously not in the vocabulary
complete_vocabulary_size = idx 
embd = list(np.array(index_to_embedding[idx], dtype=int)) # "int" compact print
#print("    {} --> {} --> {}".format(word, idx, embd))
word = "the"
idx = word_to_index[word]
embd = list(index_to_embedding[idx])  # "int" for compact print only.
#print("    {} --> {} --> {}".format(word, idx, embd))
# Out:
# Embedding is of shape: (400001, 300)
# This means (number of words, number of dimensions per word)
#
# The first words are words that tend occur more often.
# Note: for unknown words, the representation is an empty vector,
# and the index is the last one. The dictionnary has a limit:
#     A word --> Index in embedding --> Representation

# %%
def default_factory():
    return EVOCABSIZE  # last/unknown-word row in limited_index_to_embedding
# dictionary has the items() function, returns list of (key, value) tuples
limited_word_to_index = defaultdict(default_factory, \
    {k: v for k, v in word_to_index.items() if v < EVOCABSIZE})

# Select the first EVOCABSIZE rows to the index_to_embedding
limited_index_to_embedding = index_to_embedding[0:EVOCABSIZE,:]
# Set the unknown-word row to be all zeros as previously
limited_index_to_embedding = np.append(limited_index_to_embedding, 
    index_to_embedding[index_to_embedding.shape[0] - 1, :].\
        reshape(1,embedding_dim), 
    axis = 0)

# Delete large numpy array to clear some CPU RAM
del index_to_embedding

# Verify the new vocabulary: should get same embeddings for test sentence
# Note that a small EVOCABSIZE may yield some zero vectors for embeddings
print('\nTest sentence embeddings from vocabulary of', EVOCABSIZE, 'words:\n')
for word in words_in_test_sentence:
    word_ = word.lower()
    embedding = limited_index_to_embedding[limited_word_to_index[word_]]
    print(word_ + ": ", embedding)
# Out:
# Test sentence embeddings from vocabulary of 400000 words:
#
# the:  [ 4.6560e-02  2.1318e-01 -7.4364e-03 -4.5854e-01 -3.5639e-02  2.3643e-01
#  -2.8836e-01  2.1521e-01 -1.3486e-01 -1.6413e+00 -2.6091e-01  3.2434e-02
#   5.6621e-02 -4.3296e-02 -2.1672e-02  2.2476e-01 -7.5129e-02 -6.7018e-02
#  -1.4247e-01  3.8825e-02 -1.8951e-01  2.9977e-01  3.9305e-01  1.7887e-01
#  -1.7343e-01 -2.1178e-01  2.3617e-01 -6.3681e-02 -4.2318e-01 -1.1661e-01
#   9.3754e-02  1.7296e-01 -3.3073e-01  4.9112e-01 -6.8995e-01 -9.2462e-02
#   2.4742e-01 -1.7991e-01  9.7908e-02  8.3118e-02  1.5299e-01 -2.7276e-01
#  -3.8934e-02  5.4453e-01  5.3737e-01  2.9105e-01 -7.3514e-03  4.7880e-02
#  -4.0760e-01 -2.6759e-02  1.7919e-01  1.0977e-02 -1.0963e-01 -2.6395e-01
#   7.3990e-02  2.6236e-01 -1.5080e-01  3.4623e-01  2.5758e-01  1.1971e-01
#  -3.7135e-02 -7.1593e-02  4.3898e-01 -4.0764e-02  1.6425e-02 -4.4640e-01
#   1.7197e-01  4.6246e-02  5.8639e-02  4.1499e-02  5.3948e-01  5.2495e-01
#   1.1361e-01 -4.8315e-02 -3.6385e-01  1.8704e-01  9.2761e-02 -1.1129e-01
#  -4.2085e-01  1.3992e-01 -3.9338e-01 -6.7945e-02  1.2188e-01  1.6707e-01
#   7.5169e-02 -1.5529e-02 -1.9499e-01  1.9638e-01  5.3194e-02  2.5170e-01
#  -3.4845e-01 -1.0638e-01 -3.4692e-01 -1.9024e-01 -2.0040e-01  1.2154e-01
#  -2.9208e-01  2.3353e-02 -1.1618e-01 -3.5768e-01  6.2304e-02  3.5884e-01
#   2.9060e-02  7.3005e-03  4.9482e-03 -1.5048e-01 -1.2313e-01  1.9337e-01
#   1.2173e-01  4.4503e-01  2.5147e-01  1.0781e-01 -1.7716e-01  3.8691e-02
#   8.1530e-02  1.4667e-01  6.3666e-02  6.1332e-02 -7.5569e-02 -3.7724e-01
#   5.1446e-01 -1.7911e-01 -1.2389e-01  1.8688e-01 -4.1102e-01 -7.0877e-01
#  -3.7501e-01 -6.6152e-01  6.7730e-01  3.3936e-01  5.7994e-01  6.8149e-02]

# %%
# -----------------------------------------------------
# convert positive/negative documents into numpy array
# note that reviews vary from 22 to 1052 words   
# so we use the first 20 and last 20 words of each review 
# as our word sequences for analysis
# -----------------------------------------------------
max_review_length = 0  # initialize
for doc in negative_documents:
    max_review_length = max(max_review_length, len(doc))    
for doc in positive_documents:
    max_review_length = max(max_review_length, len(doc)) 
print('max_review_length:', max_review_length) 

min_review_length = max_review_length  # initialize
for doc in negative_documents:
    min_review_length = min(min_review_length, len(doc))    
for doc in positive_documents:
    min_review_length = min(min_review_length, len(doc)) 
print('min_review_length:', min_review_length) 

# construct list of 1000 lists with 40 words in each list
from itertools import chain
documents = []
for doc in negative_documents:
    doc_begin = doc[0:20]
    doc_end = doc[len(doc) - 20: len(doc)]
    documents.append(list(chain(*[doc_begin, doc_end])))    
for doc in positive_documents:
    doc_begin = doc[0:20]
    doc_end = doc[len(doc) - 20: len(doc)]
    documents.append(list(chain(*[doc_begin, doc_end])))    

# create list of lists of lists for embeddings
embeddings = []    
for doc in documents:
    embedding = []
    for word in doc:
       embedding.append(limited_index_to_embedding[limited_word_to_index[word]]) 
    embeddings.append(embedding)
    
# embeddings
# Out:
# max_review_length: 1052
# min_review_length: 22

# %%
# -----------------------------------------------------    
# Check on the embeddings list of list of lists 
# -----------------------------------------------------
# Show the first word in the first document
test_word = documents[0][0]    
print('First word in first document:', test_word)    
print('Embedding for this word:\n', 
      limited_index_to_embedding[limited_word_to_index[test_word]])
print('Corresponding embedding from embeddings list of list of lists\n',
      embeddings[0][0][:])

# Show the seventh word in the tenth document
test_word = documents[6][9]    
print('First word in first document:', test_word)    
print('Embedding for this word:\n', 
      limited_index_to_embedding[limited_word_to_index[test_word]])
print('Corresponding embedding from embeddings list of list of lists\n',
      embeddings[6][9][:])

# Show the last word in the last document
test_word = documents[999][39]    
print('First word in first document:', test_word)    
print('Embedding for this word:\n', 
      limited_index_to_embedding[limited_word_to_index[test_word]])
print('Corresponding embedding from embeddings list of list of lists\n',
      embeddings[999][39][:])
# Out:
# First word in first document: which
# Embedding for this word:
#  [-2.2232e-01  2.3856e-01 -4.8047e-02 -2.5248e-01 -8.2310e-02  1.0927e-01
#  -1.5009e-02  3.6736e-01  9.7258e-02 -2.1902e+00  2.5305e-01  1.5526e-01
#   1.6028e-01 -2.5013e-01  5.3829e-01  2.5968e-01 -3.7403e-01  2.1711e-01
#   1.1890e-01 -2.3249e-01 -2.5872e-02  4.1508e-01  1.5975e-01  1.3737e-01
#  -2.5127e-01  2.7905e-02 -4.7097e-02 -1.6902e-01 -3.0578e-01  1.6238e-01
#   2.7640e-01  3.7674e-01 -2.1659e-01  2.8674e-01 -4.1485e-01 -1.1651e-01
#   1.1826e-01  3.9304e-02 -1.8228e-01 -3.1823e-01 -2.5248e-01  7.6281e-02
#  -3.2283e-01  1.2200e-01  5.5340e-02  9.5988e-02 -1.0934e-01 -1.1307e-01
#   0.23786    0.11785   -0.40099   -0.063524   0.19127   -0.42782
#  -0.51856   -0.0039714  0.11763   -0.15962    0.051299   0.41019
#   0.3065     0.32734   -0.22244   -0.096913   0.30338    0.040716
#   0.032069   0.43869    0.14033   -0.22016   -0.069715  -0.51407
#   0.48688   -0.17321   -0.26318    0.15112   -0.30975   -0.4964
#  -0.15772   -0.0093385 -0.27849   -0.012445  -0.11668    0.35457
#  -0.061062   0.22758    0.38985   -0.22907   -0.2172    -0.017055
#   0.26321   -0.65449    0.36185   -0.20883    0.25764    0.70301
#  -0.21204   -0.0079166 -0.24678   -0.15431   -0.085402  -0.1474
#  -0.42116    0.012344   0.21556    0.1596    -0.011567  -0.51497
#   1.0139    -0.15574    0.22414   -0.19117    0.47897    0.2092
#   0.069411   0.070464   0.03683   -0.13078   -0.27006   -0.020633
#   0.055389  -0.29062   -0.13219    0.13626    0.23973   -0.37244
#   0.43342    0.24354    0.010246   0.059118  -0.55379    0.22247
#  -0.48245   -0.030428   0.4412     0.087666   0.10268    0.7162
#  -0.17578    0.075311  -0.16964    0.18787   -0.12148   -0.10357
#  -0.50315   -0.27002    0.5676    -0.05969   -0.56119    0.36339
#   0.036121   0.16803    0.11594   -0.335      0.10189   -0.85143
#   0.028631   0.39692    1.0248    -0.32314   -0.040714  -0.17541
#  -0.018877   0.069754  -0.46688    0.47933    0.25042   -0.37276
#   0.30773    0.041564  -0.45206   -0.21407    0.50525    0.41875
#   0.21413   -0.13878   -0.14075    0.23988    0.26352   -0.56183
#   0.13925    0.13151   -0.15621   -0.022536   0.21291    0.24885
#   0.43979    0.1153    -0.32596   -0.15852   -0.30176   -0.34875
#   0.38491   -0.089261   0.58249   -0.13312    0.15149    0.0031835
#   0.10651   -0.14428    0.23015    0.31781   -0.86813   -0.08598
#   0.15936   -0.11203   -0.47009    0.25234    0.088992  -0.47609
#   0.12176   -0.14096    0.061011   0.2723    -0.24595   -0.32956
#  -0.059917   0.40184   -0.059465  -0.1311    -0.13948    0.06352
#   0.44515    0.11023    0.25526   -0.060008  -0.53159    0.12914
#   0.19703   -0.08676   -0.22265   -0.02535   -0.10499   -0.42133
#  -2.3605    -0.035012   0.11352   -0.055027  -0.36112   -0.16003
#  -0.24369    0.092209  -0.013687   0.49693    0.17455    0.42357
#   0.21279   -0.45023    0.12847   -0.039041   0.51096    0.2658
#   0.34563    0.055152   0.052018  -0.44912    0.17152   -0.075024 ]

# %%
RANDOM_SEED = 9999
# -----------------------------------------------------    
# Make embeddings a numpy array for use in an RNN 
# Create training and test sets with Scikit Learn
# -----------------------------------------------------
embeddings_array = np.array(embeddings)

# Define the labels to be used 500 negative (0) and 500 positive (1)
thumbs_down_up = np.concatenate((np.zeros((500), dtype = np.int32), 
                      np.ones((500), dtype = np.int32)), axis = 0)

# Scikit Learn for random splitting of the data  
from sklearn.model_selection import train_test_split

# Random splitting of the data in to training (80%) and test (20%)  
X_train, X_test, y_train, y_test = \
    train_test_split(embeddings_array, thumbs_down_up, test_size=0.20, 
                     random_state = RANDOM_SEED)

# %% [markdown]
# ###Model 2a - simple RNN (300d)

# %%
reset_graph()

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up

learning_rate = 0.001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

basic_cell = tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
outputs, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)

logits = tf.layers.dense(states, n_outputs)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,
                                                          logits=logits)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

n_epochs = 50
batch_size = 100

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ac4c1f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ac4c1f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ac4c1f50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ac4c1f50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19ddd45d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19ddd45d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19ddd45d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb19ddd45d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
#   ---- Epoch  0  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.52 Test accuracy: 0.525
#
#   ---- Epoch  1  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.55 Test accuracy: 0.57
#
#   ---- Epoch  2  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.63 Test accuracy: 0.565
#
#   ---- Epoch  3  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.66 Test accuracy: 0.545
#
#   ---- Epoch  4  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.68 Test accuracy: 0.55
#
#   ---- Epoch  5  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.69 Test accuracy: 0.545
#
#   ---- Epoch  6  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.69 Test accuracy: 0.545
#
#   ---- Epoch  7  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.71 Test accuracy: 0.55
#
#   ---- Epoch  8  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.57
#
#   ---- Epoch  9  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.575
#
#   ---- Epoch  10  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.59
#
#   ---- Epoch  11  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.605
#
#   ---- Epoch  12  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.59
#
#   ---- Epoch  13  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.585
#
#   ---- Epoch  14  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.595
#
#   ---- Epoch  15  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.88 Test accuracy: 0.6
#
#   ---- Epoch  16  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.605
#
#   ---- Epoch  17  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.605
#
#   ---- Epoch  18  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.9 Test accuracy: 0.605
#
#   ---- Epoch  19  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.595
#
#   ---- Epoch  20  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.91 Test accuracy: 0.59
#
#   ---- Epoch  21  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.595
#
#   ---- Epoch  22  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.91 Test accuracy: 0.605
#
#   ---- Epoch  23  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.605
#
#   ---- Epoch  24  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.615
#
#   ---- Epoch  25  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.93 Test accuracy: 0.61
#
#   ---- Epoch  26  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.6
#
#   ---- Epoch  27  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.94 Test accuracy: 0.615
#
#   ---- Epoch  28  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.95 Test accuracy: 0.615
#
#   ---- Epoch  29  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.62
#
#   ---- Epoch  30  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.61
#
#   ---- Epoch  31  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.615
#
#   ---- Epoch  32  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.96 Test accuracy: 0.61
#
#   ---- Epoch  33  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.625
#
#   ---- Epoch  34  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.63
#
#   ---- Epoch  35  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.615
#
#   ---- Epoch  36  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.97 Test accuracy: 0.605
#
#   ---- Epoch  37  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.92 Test accuracy: 0.625
#
#   ---- Epoch  38  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.605
#
#   ---- Epoch  39  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.61
#
#   ---- Epoch  40  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.62
#
#   ---- Epoch  41  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.98 Test accuracy: 0.625
#
#   ---- Epoch  42  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.99 Test accuracy: 0.61
#
#   ---- Epoch  43  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.61
#
#   ---- Epoch  44  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.62
#
#   ---- Epoch  45  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.64
#
#   ---- Epoch  46  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.625
#
#   ---- Epoch  47  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.625
#
#   ---- Epoch  48  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.635
#
#   ---- Epoch  49  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 1.0 Test accuracy: 0.65

# %% [markdown]
# ###Model 2b - Long Short Term Memory (LSTM) Model

# %%
# %%time
reset_graph()

lstm_cell = tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up
n_layers = 3

learning_rate = 0.0001

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

lstm_cells = [tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)
              for layer in range(n_layers)]
multi_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)
outputs, states = tf.nn.dynamic_rnn(multi_cell, X, dtype=tf.float32)
top_layer_h_state = states[-1][1]
logits = tf.layers.dense(top_layer_h_state, n_outputs, name="softmax")
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy, name="loss")
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()

n_epochs = 50
batch_size = 100

'''with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print("Epoch", epoch, "Train accuracy =", acc_train, "Test accuracy =", acc_test)'''

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb1943b8a90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb1943b8a90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb1943b8a90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb1943b8a90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbd10>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb19a1cbd10>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b8350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b8350>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b8350>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b8350>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b84d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b84d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b84d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicLSTMCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7fb1943b84d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ab3199d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ab3199d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ab3199d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb1ab3199d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 0 Train accuracy = 0.49 Test accuracy = 0.5
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 1 Train accuracy = 0.52 Test accuracy = 0.515
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 2 Train accuracy = 0.52 Test accuracy = 0.51
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 3 Train accuracy = 0.52 Test accuracy = 0.51
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 4 Train accuracy = 0.53 Test accuracy = 0.515
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 5 Train accuracy = 0.55 Test accuracy = 0.515
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 6 Train accuracy = 0.56 Test accuracy = 0.515
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 7 Train accuracy = 0.56 Test accuracy = 0.55
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 8 Train accuracy = 0.58 Test accuracy = 0.56
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 9 Train accuracy = 0.6 Test accuracy = 0.595
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 10 Train accuracy = 0.68 Test accuracy = 0.605
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 11 Train accuracy = 0.7 Test accuracy = 0.615
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 12 Train accuracy = 0.72 Test accuracy = 0.63
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 13 Train accuracy = 0.71 Test accuracy = 0.635
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 14 Train accuracy = 0.73 Test accuracy = 0.645
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 15 Train accuracy = 0.73 Test accuracy = 0.65
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 16 Train accuracy = 0.75 Test accuracy = 0.645
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 17 Train accuracy = 0.75 Test accuracy = 0.655
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 18 Train accuracy = 0.77 Test accuracy = 0.66
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 19 Train accuracy = 0.76 Test accuracy = 0.665
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 20 Train accuracy = 0.77 Test accuracy = 0.675
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 21 Train accuracy = 0.77 Test accuracy = 0.68
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 22 Train accuracy = 0.78 Test accuracy = 0.69
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 23 Train accuracy = 0.8 Test accuracy = 0.695
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 24 Train accuracy = 0.81 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 25 Train accuracy = 0.8 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 26 Train accuracy = 0.8 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 27 Train accuracy = 0.81 Test accuracy = 0.705
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 28 Train accuracy = 0.82 Test accuracy = 0.7
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 29 Train accuracy = 0.82 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 30 Train accuracy = 0.84 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 31 Train accuracy = 0.84 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 32 Train accuracy = 0.85 Test accuracy = 0.705
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 33 Train accuracy = 0.85 Test accuracy = 0.705
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 34 Train accuracy = 0.85 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 35 Train accuracy = 0.85 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 36 Train accuracy = 0.85 Test accuracy = 0.71
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 37 Train accuracy = 0.85 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 38 Train accuracy = 0.85 Test accuracy = 0.715
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 39 Train accuracy = 0.86 Test accuracy = 0.725
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 40 Train accuracy = 0.86 Test accuracy = 0.72
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 41 Train accuracy = 0.85 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 42 Train accuracy = 0.86 Test accuracy = 0.725
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 43 Train accuracy = 0.87 Test accuracy = 0.72
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 44 Train accuracy = 0.86 Test accuracy = 0.72
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 45 Train accuracy = 0.86 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 46 Train accuracy = 0.86 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 47 Train accuracy = 0.86 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 48 Train accuracy = 0.86 Test accuracy = 0.73
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
# Epoch 49 Train accuracy = 0.86 Test accuracy = 0.725
# CPU times: user 52.1 s, sys: 3.08 s, total: 55.2 s
# Wall time: 32.1 s

# %% [markdown]
# ###Model 2c - RNN model using drop cell
#
# train accuracy:
#
# test accuracy:
#
# time:

# %%
# %%time
reset_graph()

# lstm_cell = tf.contrib.rnn.BasicLSTMCell(num_units=n_neurons)

n_steps = embeddings_array.shape[1]  # number of words per document 
n_inputs = embeddings_array.shape[2]  # dimension of  pre-trained embeddings
n_neurons = 20  # analyst specified number of neurons
n_outputs = 2  # thumbs-down or thumbs-up
n_layers = 3

learning_rate = 0.01

X = tf.placeholder(tf.float32, [None, n_steps, n_inputs])
y = tf.placeholder(tf.int32, [None])

keep_prob = tf.placeholder_with_default(.5, shape=())
cells = [tf.contrib.rnn.BasicRNNCell(num_units=n_neurons)
         for layer in range(n_layers)]
cells_drop = [tf.contrib.rnn.DropoutWrapper(cell, input_keep_prob=keep_prob)
              for cell in cells]
multi_layer_cell = tf.contrib.rnn.MultiRNNCell(cells_drop)
outputs, states = tf.nn.dynamic_rnn(multi_layer_cell, X, dtype=tf.float32)

states_concat = tf.concat(axis=1, values=states)
logits = tf.layers.dense(states_concat, n_outputs)
xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
loss = tf.reduce_mean(xentropy)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)
correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
        
n_epochs = 100
batch_size = 100

'''with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(y_train.shape[0] // batch_size):
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            X_batch = X_batch.reshape((-1, n_steps, n_inputs))
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)'''

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        print('\n  ---- Epoch ', epoch, ' ----\n')
        for iteration in range(y_train.shape[0] // batch_size):          
            X_batch = X_train[iteration*batch_size:(iteration + 1)*batch_size,:]
            y_batch = y_train[iteration*batch_size:(iteration + 1)*batch_size]
            print('  Batch ', iteration, ' training observations from ',  
                  iteration*batch_size, ' to ', (iteration + 1)*batch_size-1,)
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_test = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print('\n  Train accuracy:', acc_train, 'Test accuracy:', acc_test)
# Out:
# WARNING:tensorflow:Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a4f3d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a4f3d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a4f3d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method MultiRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.MultiRNNCell object at 0x7fb194a4f3d0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ab1b2f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ab1b2f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ab1b2f90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb1ab1b2f90>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4f8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4f8d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4f8d0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4f8d0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4fc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4fc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4fc50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method BasicRNNCell.call of <tensorflow.python.ops.rnn_cell_impl.BasicRNNCell object at 0x7fb194a4fc50>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb194a4fad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb194a4fad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
# WARNING: Entity <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb194a4fad0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Dense.call of <tensorflow.python.layers.core.Dense object at 0x7fb194a4fad0>>: AssertionError: Bad argument number for Name: 3, expecting 4
#
#   ---- Epoch  0  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.57 Test accuracy: 0.525
#
#   ---- Epoch  1  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.6 Test accuracy: 0.56
#
#   ---- Epoch  2  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.65 Test accuracy: 0.52
#
#   ---- Epoch  3  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.69 Test accuracy: 0.6
#
#   ---- Epoch  4  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.76 Test accuracy: 0.575
#
#   ---- Epoch  5  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.71 Test accuracy: 0.575
#
#   ---- Epoch  6  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.77 Test accuracy: 0.6
#
#   ---- Epoch  7  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.58
#
#   ---- Epoch  8  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.595
#
#   ---- Epoch  9  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.64
#
#   ---- Epoch  10  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.59
#
#   ---- Epoch  11  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.7 Test accuracy: 0.605
#
#   ---- Epoch  12  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.77 Test accuracy: 0.615
#
#   ---- Epoch  13  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.585
#
#   ---- Epoch  14  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.72 Test accuracy: 0.585
#
#   ---- Epoch  15  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.605
#
#   ---- Epoch  16  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.595
#
#   ---- Epoch  17  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.8 Test accuracy: 0.615
#
#   ---- Epoch  18  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.605
#
#   ---- Epoch  19  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.655
#
#   ---- Epoch  20  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.645
#
#   ---- Epoch  21  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.8 Test accuracy: 0.605
#
#   ---- Epoch  22  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.605
#
#   ---- Epoch  23  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.585
#
#   ---- Epoch  24  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.635
#
#   ---- Epoch  25  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.61
#
#   ---- Epoch  26  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.62
#
#   ---- Epoch  27  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.625
#
#   ---- Epoch  28  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.605
#
#   ---- Epoch  29  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.9 Test accuracy: 0.59
#
#   ---- Epoch  30  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.605
#
#   ---- Epoch  31  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.78 Test accuracy: 0.58
#
#   ---- Epoch  32  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.73 Test accuracy: 0.575
#
#   ---- Epoch  33  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.74 Test accuracy: 0.65
#
#   ---- Epoch  34  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.8 Test accuracy: 0.54
#
#   ---- Epoch  35  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.77 Test accuracy: 0.575
#
#   ---- Epoch  36  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.635
#
#   ---- Epoch  37  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.78 Test accuracy: 0.57
#
#   ---- Epoch  38  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.615
#
#   ---- Epoch  39  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.56
#
#   ---- Epoch  40  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.77 Test accuracy: 0.575
#
#   ---- Epoch  41  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.6
#
#   ---- Epoch  42  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.645
#
#   ---- Epoch  43  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.88 Test accuracy: 0.635
#
#   ---- Epoch  44  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.605
#
#   ---- Epoch  45  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.75 Test accuracy: 0.615
#
#   ---- Epoch  46  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.91 Test accuracy: 0.59
#
#   ---- Epoch  47  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.88 Test accuracy: 0.64
#
#   ---- Epoch  48  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.625
#
#   ---- Epoch  49  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.625
#
#   ---- Epoch  50  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.88 Test accuracy: 0.57
#
#   ---- Epoch  51  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.665
#
#   ---- Epoch  52  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.63
#
#   ---- Epoch  53  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.605
#
#   ---- Epoch  54  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.645
#
#   ---- Epoch  55  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.59
#
#   ---- Epoch  56  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.625
#
#   ---- Epoch  57  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.635
#
#   ---- Epoch  58  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.77 Test accuracy: 0.555
#
#   ---- Epoch  59  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.78 Test accuracy: 0.625
#
#   ---- Epoch  60  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.78 Test accuracy: 0.57
#
#   ---- Epoch  61  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.605
#
#   ---- Epoch  62  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.73 Test accuracy: 0.62
#
#   ---- Epoch  63  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.58
#
#   ---- Epoch  64  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.8 Test accuracy: 0.59
#
#   ---- Epoch  65  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.61
#
#   ---- Epoch  66  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.555
#
#   ---- Epoch  67  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.625
#
#   ---- Epoch  68  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.8 Test accuracy: 0.595
#
#   ---- Epoch  69  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.63
#
#   ---- Epoch  70  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.63
#
#   ---- Epoch  71  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.6
#
#   ---- Epoch  72  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.58
#
#   ---- Epoch  73  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.84 Test accuracy: 0.585
#
#   ---- Epoch  74  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.79 Test accuracy: 0.625
#
#   ---- Epoch  75  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.62
#
#   ---- Epoch  76  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.6
#
#   ---- Epoch  77  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.635
#
#   ---- Epoch  78  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.6
#
#   ---- Epoch  79  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.585
#
#   ---- Epoch  80  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.555
#
#   ---- Epoch  81  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.62
#
#   ---- Epoch  82  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.64
#
#   ---- Epoch  83  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.9 Test accuracy: 0.65
#
#   ---- Epoch  84  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.62
#
#   ---- Epoch  85  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.6
#
#   ---- Epoch  86  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.635
#
#   ---- Epoch  87  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.63
#
#   ---- Epoch  88  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.82 Test accuracy: 0.625
#
#   ---- Epoch  89  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.605
#
#   ---- Epoch  90  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.89 Test accuracy: 0.6
#
#   ---- Epoch  91  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.9 Test accuracy: 0.64
#
#   ---- Epoch  92  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.615
#
#   ---- Epoch  93  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.53
#
#   ---- Epoch  94  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.81 Test accuracy: 0.615
#
#   ---- Epoch  95  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.86 Test accuracy: 0.6
#
#   ---- Epoch  96  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.85 Test accuracy: 0.63
#
#   ---- Epoch  97  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.61
#
#   ---- Epoch  98  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.83 Test accuracy: 0.635
#
#   ---- Epoch  99  ----
#
#   Batch  0  training observations from  0  to  99
#   Batch  1  training observations from  100  to  199
#   Batch  2  training observations from  200  to  299
#   Batch  3  training observations from  300  to  399
#   Batch  4  training observations from  400  to  499
#   Batch  5  training observations from  500  to  599
#   Batch  6  training observations from  600  to  699
#   Batch  7  training observations from  700  to  799
#
#   Train accuracy: 0.87 Test accuracy: 0.56
# CPU times: user 1min 13s, sys: 3.02 s, total: 1min 16s
# Wall time: 42.8 s

# %% [markdown]
# ##Summary
#
# Recommend using Model 1c a RNN model using drop cell method to avoid over training with the highest accuracy.
